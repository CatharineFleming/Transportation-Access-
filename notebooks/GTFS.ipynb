# %%
# !pip install gtfs_functions

# %%
# !pip install gtfs_kit

# %%
#import packages
from gtfs_functions import Feed
import gtfs_kit as gk
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.ops import unary_union
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import GTFS and Census Tract data

# %%
#Bring in GTFS data using gtfs_functions

#Change path to local GTFS zip
gtfs_path = r"C:\Users\cathk\GEOG490\google_transit.zip"
feed = Feed(gtfs_path, time_windows=[0, 6, 10, 12, 16, 19, 24])

# %%
routes = feed.routes
trips = feed.trips
stops = feed.stops
stop_times = feed.stop_times
shapes = feed.shapes
calendar = feed.calendar
# Out:
# INFO:root:Reading "routes.txt".
# INFO:root:accessing trips
# INFO:root:Start date is None. You should either specify a start date or set busiest_date to True.
# INFO:root:Reading "trips.txt".
# INFO:root:Reading "calendar.txt".
# INFO:root:Reading "calendar_dates.txt".
# INFO:root:The busiest date/s of this feed or your selected date range is/are:  ['2024-05-27'] with 27665 trips.
# INFO:root:In the case that more than one busiest date was found, the first one will be considered.
# INFO:root:In this case is 2024-05-27.
# INFO:root:Reading "stop_times.txt".
# INFO:root:_trips is defined in stop_times
# INFO:root:Reading "stops.txt".
# INFO:root:computing patterns
# INFO:root:Reading "shapes.txt".

# %%
#Bring in Census Tract Data

#Change path to local tract shapefile
tracts = gpd.read_file(r"C:\Users\cathk\GEOG490\tl_2021_17_tract\tl_2021_17_tract.shp")

#Get Cook county Census tract
cook_tracts = tracts[tracts['COUNTYFP'] == '031']

#Reproject  Cook tracts to UTM 
cook_tracts = cook_tracts.to_crs("EPSG:32616")
# Out:
# ERROR:fiona._env:PROJ: proj_identify: C:\Users\cathk\miniconda3\Library\share\proj\proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.
# ERROR:fiona._env:PROJ: proj_identify: C:\Users\cathk\miniconda3\Library\share\proj\proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.

# %%
# Extract needed columns
cook_tracts = cook_tracts[['TRACTCE','ALAND','AWATER','geometry']]

# %% [markdown]
# # Transit Factors and Indicators

# %% [markdown]
# ### Factor 1: Connectivity to the Network
# ##### Indicators: Bus stop service coverage area, density of bus stops, route coverage, ADA accessibility

# %% [markdown]
# #### Indicator: Bus stop service coverage area
# Bus stop service coverage area is determined by finding the sum of the service coverage areas of bus stops in a Census tract divided by the total area of the Census tract.
#
#  - Service coverage areas are 400m radius buffers from each bus stop. Here overlapping areas are counted one time.

# %%
# Bring in the bus stops
stops = feed.stops

#Reproject the bus stops to UTM
stops_reproject = stops.to_crs("EPSG:32616")

#buffer stops 
buffer_distance = 400 #meters
stops_buffered = stops_reproject.buffer(buffer_distance)

#Convert buffered stops geoseries to a geodataframe
stops_buffered_gdf = gpd.GeoDataFrame(geometry=stops_buffered)

# %%
# Calculate the intersection areas
cook_tracts['area'] = cook_tracts.geometry.area

# %%
# Merge all the polygons into a single polygon
merged_polygon = unary_union(stops_buffered_gdf.geometry)

# Create a new GeoDataFrame with the merged polygon
merged_gdf = gpd.GeoDataFrame(geometry=[merged_polygon])

# If you want to reset the index of the DataFrame
merged_gdf.reset_index(drop=True, inplace=True)

# %%
# Create an empty list to store the results
area_covered_list = []

# Iterate over each row in gdf2
for _, row in cook_tracts.iterrows():
    # Calculate the intersection between the row geometry of gdf2 and the geometries in gdf1
    intersection = merged_gdf.intersection(row.geometry)
    
    # Calculate the total area of the intersection
    total_intersection_area = intersection.area.sum()
    
    # Append the total intersection area to the list
    area_covered_list.append(total_intersection_area)

# Add the area_covered_list as a new column to gdf2
cook_tracts['area_covered'] = area_covered_list

# %%
cook_tracts['service_coverage']=cook_tracts['area_covered']/cook_tracts['area']

# %% [markdown]
# #### Indicator: Density of bus stops
# The density of bus stops is determined by dividing the number of bus stops in a census tract by the area of the census tract

# %%
#Get the number of bus stops in a census tract

stops_county = stops_reproject.sjoin(cook_tracts, how="left")

stops_county['area'] = stops_county['geometry'].area


unique, counts = np.unique(stops_county['TRACTCE'], return_counts=True)
dict(zip(unique, counts))


busstopsincounty = gpd.GeoDataFrame(list(zip(unique, counts)), 
                       columns=['TRACTCE', 'bus_stops'])

cook_tracts = cook_tracts.merge(busstopsincounty, on='TRACTCE', how='left')
cook_tracts['density_bstops'] = cook_tracts['bus_stops']/cook_tracts['area']

# %% [markdown]
# #### Indicator: Route coverage
# Route coverage quantifies the distribution and density of bus routes throughout the street network of the Census tract. This metric is calculated by taking the sum of the lengths of all routes in a census tract and dividing this by the sum of the length of the street network throughout the tract.

# %%
# Load the GTFS feed into a Feed object
feed = gk.read_feed(gtfs_path,dist_units='mi')

# %%
routesgeom = gk.routes.geometrize_routes(feed)

# %%
routesgeom

# %%
routesgeom.crs = "EPSG:4326" 

#Reproject the routes to UTM
routes_reproject = routesgeom.to_crs("EPSG:32616")

# %%
routes_reproject

# %%
# Get bus routes with type 3
routes_reproject = routes_reproject[routes_reproject['route_type'] == 3]

# %%
#sum length of bus routes in each tract

# Perform a spatial join to get the lines that intersect with the polygons
lines_within_polygons = gpd.overlay(routes_reproject, cook_tracts, how='intersection')

# Calculate the length of the resulting LineStrings
lines_within_polygons['length'] = lines_within_polygons.geometry.length

# Group by 'TRACTCE' to handle unique polygons and calculate the sum of the lengths for each
total_length_within_polygons = lines_within_polygons.groupby('TRACTCE')['length'].sum().reset_index()

total_length_within_polygons.rename(columns={'length': 'routesum'}, inplace=True)


total_length_within_polygons
# Out:
#     TRACTCE      routesum
# 0    010100    133.966434
# 1    010201   2004.417548
# 2    010202   5614.695244
# 3    010300   3520.804780
# 4    010400   3469.263037
# ..      ...           ...
# 893  843800   5001.560429
# 894  843900  31254.751262
# 895  844600   1823.464609
# 896  844700   3083.963744
# 897  980100  21079.691460
#
# [898 rows x 2 columns]

# %%
total_length_within_polygons

# %%
cook_tracts = cook_tracts.merge(total_length_within_polygons, on='TRACTCE', how='left')

# %%
cook_tracts
# Out:
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
# 1330  824123  3917329   25455
# 1331  804405  1674250       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
# 1330  POLYGON ((432193.967 4605905.521, 432261.895 4...  3.940064e+06
# 1331  POLYGON ((395425.037 4654609.787, 395432.344 4...  1.673347e+06
#
#        area_covered  service_coverage  bus_stops  density_bstops     routesum
# 0     219891.671793          1.000000        3.0        0.000014   705.074167
# 1     439728.803401          1.000000       13.0        0.000030  2512.715676
# 2     439313.154976          1.000000       13.0        0.000030  4226.811341
# 3     323587.160616          1.000000        9.0        0.000028  3520.991681
# 4     324311.806412          1.000000       12.0        0.000037  1426.360327
# ...             ...               ...        ...             ...          ...
# 1327  394215.618112          0.999416        6.0        0.000015  2670.123358
# 1328  857669.965464          0.986624       29.0        0.000033  6666.802679
# 1329  657512.146495          1.000000       19.0        0.000029  3217.475997
# 1330       0.000000          0.000000        NaN             NaN          NaN
# 1331       0.000000          0.000000        NaN             NaN          NaN
#
# [1332 rows x 10 columns]

# %%
cook_tracts.crs
# Out:
# <Projected CRS: EPSG:32616>
# Name: WGS 84 / UTM zone 16N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 90°W and 84°W, northern hemisphere between equator and 84°N, onshore and offshore. Belize. Canada - Manitoba; Nunavut; Ontario. Costa Rica. Cuba. Ecuador - Galapagos. El Salvador. Guatemala. Honduras. Mexico. Nicaragua. United States (USA).
# - bounds: (-90.0, 0.0, -84.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 16N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
cook_tracts = cook_tracts.to_crs("EPSG:32616")

# %%
# find total street network length
import osmnx as ox
import geopandas as gpd

# Define your city or region of interest
place_name = "Chicago, Illinois, USA"

network_lengths = []
for geometry in cook_tracts['geometry']:

    
    # Retrieve the street network within the boundary of the Census Tract
    G = ox.graph_from_polygon(geometry, network_type='all')
    
     # Calculate the basic statistics of the street network within the Census Tract
    stats = ox.stats.basic_stats(G)
    
    # Extract the total length of the street network within the Census Tract
    total_length = stats['edge_length_total']
    
    network_lengths.append(total_length)

    print("count")
cook_tracts['net_len'] = network_lengths
# Out:
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# count
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 16
#      13 G = ox.graph_from_polygon(geometry, network_type='all')
#      15  # Calculate the basic statistics of the street network within the Census Tract
# ---> 16 stats = ox.stats.basic_stats(G)
#      18 # Extract the total length of the street network within the Census Tract
#      19 total_length = stats['edge_length_total']
#
# File ~\.gds\lib\site-packages\osmnx\stats.py:355, in basic_stats(G, area, clean_int_tol)
#     310 def basic_stats(G, area=None, clean_int_tol=None):
#     311     """
#     312     Calculate basic descriptive geometric and topological measures of a graph.
#     313
#    (...)
#     353           - `streets_per_node_proportions` - see `streets_per_node_proportions` function documentation
#     354     """
# --> 355     Gu = convert.to_undirected(G)
#     356     stats = {}
#     358     stats["n"] = len(G.nodes)
#
# File ~\.gds\lib\site-packages\osmnx\convert.py:258, in to_undirected(G)
#     254         d["geometry"] = LineString([point_u, point_v])
#     256 # increment parallel edges' keys so we don't retain only one edge of sets
#     257 # of true parallel edges when we convert from MultiDiGraph to MultiGraph
# --> 258 G = _update_edge_keys(G)
#     260 # convert MultiDiGraph to MultiGraph, retaining edges in both directions
#     261 # of parallel edges and self-loops for now
#     262 H = nx.MultiGraph(**G.graph)
#
# File ~\.gds\lib\site-packages\osmnx\convert.py:389, in _update_edge_keys(G)
#     386 # for each group of duplicate edges
#     387 for _, group in groups:
#     388     # for each pair of edges within this group
# --> 389     for geom1, geom2 in itertools.combinations(group["geometry"], 2):
#     390         # if they don't have the same geometry, flag them as different
#     391         # streets: flag edge uvk, but not edge vuk, otherwise we would
#     392         # increment both their keys and they'll still duplicate each other
#     393         if not _is_same_geometry(geom1, geom2):
#     394             different_streets.append(group.index[0])
#
# File ~\.gds\lib\site-packages\geopandas\geodataframe.py:1475, in GeoDataFrame.__getitem__(self, key)
#    1469 def __getitem__(self, key):
#    1470     """
#    1471     If the result is a column containing only 'geometry', return a
#    1472     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1473     return a GeoDataFrame.
#    1474     """
# -> 1475     result = super().__getitem__(key)
#    1476     # Custom logic to avoid waiting for pandas GH51895
#    1477     # result is not geometry dtype for multi-indexes
#    1478     if (
#    1479         pd.api.types.is_scalar(key)
#    1480         and key == ""
#    (...)
#    1483         and not is_geometry_type(result)
#    1484     ):
#
# File ~\.gds\lib\site-packages\pandas\core\frame.py:3729, in DataFrame.__getitem__(self, key)
#    3722 # GH#45316 Return view if key is not duplicated
#    3723 # Only use drop_duplicates with duplicates for performance
#    3724 if not is_mi and (
#    3725     self.columns.is_unique
#    3726     and key in self.columns
#    3727     or key in self.columns.drop_duplicates(keep=False)
#    3728 ):
# -> 3729     return self._get_item_cache(key)
#    3731 elif is_mi and self.columns.is_unique and key in self.columns:
#    3732     return self._getitem_multilevel(key)
#
# File ~\.gds\lib\site-packages\pandas\core\frame.py:4256, in DataFrame._get_item_cache(self, item)
#    4251 if res is None:
#    4252     # All places that call _get_item_cache have unique columns,
#    4253     #  pending resolution of GH#33047
#    4255     loc = self.columns.get_loc(item)
# -> 4256     res = self._ixs(loc, axis=1)
#    4258     cache[item] = res
#    4260     # for a chain
#
# File ~\.gds\lib\site-packages\pandas\core\frame.py:3667, in DataFrame._ixs(self, i, axis)
#    3664 label = self.columns[i]
#    3666 col_mgr = self._mgr.iget(i)
# -> 3667 result = self._box_col_values(col_mgr, i)
#    3669 # this is a cached value, mark it so
#    3670 result._set_as_cached(label, self)
#
# File ~\.gds\lib\site-packages\pandas\core\frame.py:4235, in DataFrame._box_col_values(self, values, loc)
#    4233 klass = self._constructor_sliced
#    4234 # We get index=self.index bc values is a SingleDataManager
# -> 4235 return klass(values, name=name, fastpath=True).__finalize__(self)
#
# File ~\.gds\lib\site-packages\geopandas\geodataframe.py:1643, in GeoDataFrame._constructor_sliced.<locals>._geodataframe_constructor_sliced(*args, **kwargs)
#    1641 is_row_proxy = srs.index is self.columns
#    1642 if is_geometry_type(srs) and not is_row_proxy:
# -> 1643     srs = GeoSeries(srs)
#    1644 return srs
#
# File ~\.gds\lib\site-packages\geopandas\geoseries.py:230, in GeoSeries.__init__(self, data, index, crs, **kwargs)
#     227     index = s.index
#     228     name = s.name
# --> 230 super().__init__(data, index=index, name=name, **kwargs)
#     231 if not self.crs:
#     232     self.crs = crs
#
# File ~\.gds\lib\site-packages\pandas\core\series.py:517, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     514     elif manager == "array":
#     515         data = SingleArrayManager.from_array(data, index)
# --> 517 NDFrame.__init__(self, data)
#     518 self.name = name
#     519 self._set_axis(0, index)
#
# File ~\.gds\lib\site-packages\pandas\core\generic.py:281, in NDFrame.__init__(self, data, copy, attrs)
#     279     attrs = dict(attrs)
#     280 object.__setattr__(self, "_attrs", attrs)
# --> 281 object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#
# File ~\.gds\lib\site-packages\pandas\core\flags.py:50, in Flags.__init__(self, obj, allows_duplicate_labels)
#      49 def __init__(self, obj, *, allows_duplicate_labels) -> None:
# ---> 50     self._allows_duplicate_labels = allows_duplicate_labels
#      51     self._obj = weakref.ref(obj)
#
# KeyboardInterrupt:

# %%
cookforarea['route_covg'] = cookforarea['routesum']/cookforarea['net_len']

# %% [markdown]
# #### Indicator: ADA accessibility
# Here the number of stops with ADA ramps is used as a proxy for system-wide accesibility. The number of stops with ADA ramps is used here.

# %%
#Get the number of bus stops in a census tract
# Spatially join stops and census tracts
stops_county = gpd.sjoin(stops_reproject, cook_tracts, how="left")

# Filter stops with wheelchair value of 1
wheelchair_stops = stops_county[stops_county['wheelchair_boarding'] == 1]

# Count the number of wheelchair stops within each census tract
wheelchair_stops_count = wheelchair_stops.groupby('TRACTCE').size().reset_index(name='wheelchair_stops')

# Merge the counts with the cook_tracts GeoDataFrame
cook_tracts = cook_tracts.merge(wheelchair_stops_count, on='TRACTCE', how='left')

# %%
cook_tracts = cook_tracts.drop(['wheelchair_stops_x','wheelchair_stops_y'], axis=1)

# %% [markdown]
# ## Create scores from transit supply indicators

# %%
from scipy.stats import zscore

# %%
cook_tracts
# Out:
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
# 1330  824123  3917329   25455
# 1331  804405  1674250       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
# 1330  POLYGON ((432193.967 4605905.521, 432261.895 4...  3.940064e+06
# 1331  POLYGON ((395425.037 4654609.787, 395432.344 4...  1.673347e+06
#
#        area_covered  service_coverage  bus_stops  density_bstops     routesum  \
# 0     219891.671793          1.000000        3.0        0.000014   705.074167
# 1     439728.803401          1.000000       13.0        0.000030  2512.715676
# 2     439313.154976          1.000000       13.0        0.000030  4226.811341
# 3     323587.160616          1.000000        9.0        0.000028  3520.991681
# 4     324311.806412          1.000000       12.0        0.000037  1426.360327
# ...             ...               ...        ...             ...          ...
# 1327  394215.618112          0.999416        6.0        0.000015  2670.123358
# 1328  857669.965464          0.986624       29.0        0.000033  6666.802679
# 1329  657512.146495          1.000000       19.0        0.000029  3217.475997
# 1330       0.000000          0.000000        NaN             NaN          NaN
# 1331       0.000000          0.000000        NaN             NaN          NaN
#
#       wheelchair_stops
# 0                  3.0
# 1                 13.0
# 2                 13.0
# 3                  9.0
# 4                 12.0
# ...                ...
# 1327               6.0
# 1328              28.0
# 1329              19.0
# 1330               NaN
# 1331               NaN
#
# [1332 rows x 11 columns]

# %%
print("Original DataFrame:")
print(cook_tracts)
print("\nChecking for NaN values:")
print(cook_tracts.isna().sum())
cook_dropped = cook_tracts.dropna()
cook_dropped
# Out:
# Original DataFrame:
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
# 1330  824123  3917329   25455
# 1331  804405  1674250       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
# 1330  POLYGON ((432193.967 4605905.521, 432261.895 4...  3.940064e+06
# 1331  POLYGON ((395425.037 4654609.787, 395432.344 4...  1.673347e+06
#
#        area_covered  service_coverage  bus_stops  density_bstops     routesum  \
# 0     219891.671793          1.000000        3.0        0.000014   705.074167
# 1     439728.803401          1.000000       13.0        0.000030  2512.715676
# 2     439313.154976          1.000000       13.0        0.000030  4226.811341
# 3     323587.160616          1.000000        9.0        0.000028  3520.991681
# 4     324311.806412          1.000000       12.0        0.000037  1426.360327
# ...             ...               ...        ...             ...          ...
# 1327  394215.618112          0.999416        6.0        0.000015  2670.123358
# 1328  857669.965464          0.986624       29.0        0.000033  6666.802679
# 1329  657512.146495          1.000000       19.0        0.000029  3217.475997
# 1330       0.000000          0.000000        NaN             NaN          NaN
# 1331       0.000000          0.000000        NaN             NaN          NaN
#
#       wheelchair_stops
# 0                  3.0
# 1                 13.0
# 2                 13.0
# 3                  9.0
# 4                 12.0
# ...                ...
# 1327               6.0
# 1328              28.0
# 1329              19.0
# 1330               NaN
# 1331               NaN
#
# [1332 rows x 11 columns]
#
# Checking for NaN values:
# TRACTCE               0
# ALAND                 0
# AWATER                0
# geometry              0
# area                  0
# area_covered          0
# service_coverage      0
# bus_stops           445
# density_bstops      445
# routesum            434
# wheelchair_stops    447
# dtype: int64
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1324  440201   531454       0
# 1325  540101  3357305  508399
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1324  POLYGON ((448872.553 4622326.008, 448885.773 4...  5.310625e+05
# 1325  POLYGON ((448264.432 4611157.472, 448272.330 4...  3.862848e+06
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
#
#       area_covered  service_coverage  bus_stops  density_bstops     routesum  \
# 0     2.198917e+05          1.000000        3.0        0.000014   705.074167
# 1     4.397288e+05          1.000000       13.0        0.000030  2512.715676
# 2     4.393132e+05          1.000000       13.0        0.000030  4226.811341
# 3     3.235872e+05          1.000000        9.0        0.000028  3520.991681
# 4     3.243118e+05          1.000000       12.0        0.000037  1426.360327
# ...            ...               ...        ...             ...          ...
# 1324  5.303250e+05          0.998611       12.0        0.000023  1961.940422
# 1325  1.173475e+06          0.303785       13.0        0.000003  4995.748628
# 1327  3.942156e+05          0.999416        6.0        0.000015  2670.123358
# 1328  8.576700e+05          0.986624       29.0        0.000033  6666.802679
# 1329  6.575121e+05          1.000000       19.0        0.000029  3217.475997
#
#       wheelchair_stops
# 0                  3.0
# 1                 13.0
# 2                 13.0
# 3                  9.0
# 4                 12.0
# ...                ...
# 1324              12.0
# 1325              13.0
# 1327               6.0
# 1328              28.0
# 1329              19.0
#
# [881 rows x 11 columns]

# %%
# List of columns to convert to numeric
columns_to_convert = ['percent_higher_ed', 'percent_vehicle_access', 'percent_employed',
       'percent_citizen', 'percent_english_speaking', 'percent_older_60',
       'percent_younger_19', 'percent_disability', 'percent_transit']

# Convert specified columns to numeric
df[columns_to_convert] = df[columns_to_convert].apply(lambda col: pd.to_numeric(col, errors='coerce'))

print("\nDataFrame after converting specified columns to numeric:")
print(df)

# %%
# Standarize Data
columns_to_standardize = ['service_coverage','density_bstops','routesum','wheelchair_stops']

# Calculate z-scores for the specified columns
cook_dropped[columns_to_standardize] = cook_dropped[columns_to_standardize].apply(zscore)
print("\nDataFrame with z-scores:")
print(cook_dropped)
# Out:
# DataFrame with z-scores:
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1324  440201   531454       0
# 1325  540101  3357305  508399
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1324  POLYGON ((448872.553 4622326.008, 448885.773 4...  5.310625e+05
# 1325  POLYGON ((448264.432 4611157.472, 448272.330 4...  3.862848e+06
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
#
#       area_covered  service_coverage  bus_stops  density_bstops  routesum  \
# 0     2.198917e+05          0.538065        3.0       -0.570574 -0.676593
# 1     4.397288e+05          0.538065       13.0        0.607097 -0.335144
# 2     4.393132e+05          0.538065       13.0        0.609166 -0.011365
# 3     3.235872e+05          0.538065        9.0        0.477613 -0.144689
# 4     3.243118e+05          0.538065       12.0        1.157279 -0.540348
# ...            ...               ...        ...             ...       ...
# 1324  5.303250e+05          0.531499       12.0        0.091703 -0.439181
# 1325  1.173475e+06         -2.753697       13.0       -1.330830  0.133881
# 1327  3.942156e+05          0.535305        6.0       -0.454577 -0.305411
# 1328  8.576700e+05          0.474823       29.0        0.887937  0.449529
# 1329  6.575121e+05          0.538065       19.0        0.557767 -0.202021
#
#       wheelchair_stops
# 0            -1.121122
# 1             0.055983
# 2             0.055983
# 3            -0.414859
# 4            -0.061728
# ...                ...
# 1324         -0.061728
# 1325          0.055983
# 1327         -0.767990
# 1328          1.821639
# 1329          0.762245
#
# [881 rows x 11 columns]

# %%
# Sum the z-scores across the specified columns
cook_dropped['transit_supply_score'] = cook_dropped[columns_to_standardize].sum(axis=1)
print("\nDataFrame with transit supply scores:")
print(cook_dropped)
# Out:
# DataFrame with transit supply scores:
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1324  440201   531454       0
# 1325  540101  3357305  508399
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1324  POLYGON ((448872.553 4622326.008, 448885.773 4...  5.310625e+05
# 1325  POLYGON ((448264.432 4611157.472, 448272.330 4...  3.862848e+06
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
#
#       area_covered  service_coverage  bus_stops  density_bstops  routesum  \
# 0     2.198917e+05          0.538065        3.0       -0.570574 -0.676593
# 1     4.397288e+05          0.538065       13.0        0.607097 -0.335144
# 2     4.393132e+05          0.538065       13.0        0.609166 -0.011365
# 3     3.235872e+05          0.538065        9.0        0.477613 -0.144689
# 4     3.243118e+05          0.538065       12.0        1.157279 -0.540348
# ...            ...               ...        ...             ...       ...
# 1324  5.303250e+05          0.531499       12.0        0.091703 -0.439181
# 1325  1.173475e+06         -2.753697       13.0       -1.330830  0.133881
# 1327  3.942156e+05          0.535305        6.0       -0.454577 -0.305411
# 1328  8.576700e+05          0.474823       29.0        0.887937  0.449529
# 1329  6.575121e+05          0.538065       19.0        0.557767 -0.202021
#
#       wheelchair_stops  transit_supply_score
# 0            -1.121122             -1.830223
# 1             0.055983              0.866000
# 2             0.055983              1.191848
# 3            -0.414859              0.456130
# 4            -0.061728              1.093268
# ...                ...                   ...
# 1324         -0.061728              0.122292
# 1325          0.055983             -3.894664
# 1327         -0.767990             -0.992674
# 1328          1.821639              3.633928
# 1329          0.762245              1.656057
#
# [881 rows x 12 columns]

# %%
# Group the transit supply scores into quartiles
cook_dropped['quartile'] = pd.qcut(cook_dropped['transit_supply_score'], 4, labels=['Low', 'Moderate-Low', 'Moderate-High', 'High'])
print("\nDataFrame with transit supply score quartiles:")
print(cook_dropped)
# Out:
# DataFrame with transit supply score quartiles:
#      TRACTCE    ALAND  AWATER  \
# 0     221000   220053       0
# 1     221100   440042       0
# 2     242800   439630       0
# 3     242900   323819       0
# 4     243000   324547       0
# ...      ...      ...     ...
# 1324  440201   531454       0
# 1325  540101  3357305  508399
# 1327  050300   380031   14700
# 1328  830700   861986    7945
# 1329  834700   657991       0
#
#                                                geometry          area  \
# 0     POLYGON ((440550.049 4641653.581, 440570.365 4...  2.198917e+05
# 1     POLYGON ((440820.061 4641655.880, 440826.943 4...  4.397288e+05
# 2     POLYGON ((442206.390 4638425.562, 442226.962 4...  4.393132e+05
# 3     POLYGON ((443024.390 4638428.848, 443065.044 4...  3.235872e+05
# 4     POLYGON ((443430.438 4638434.936, 443471.091 4...  3.243118e+05
# ...                                                 ...           ...
# 1324  POLYGON ((448872.553 4622326.008, 448885.773 4...  5.310625e+05
# 1325  POLYGON ((448264.432 4611157.472, 448272.330 4...  3.862848e+06
# 1327  POLYGON ((442426.603 4645709.824, 442440.277 4...  3.944459e+05
# 1328  POLYGON ((444814.024 4645731.063, 444830.929 4...  8.692976e+05
# 1329  POLYGON ((445994.015 4627135.510, 446006.889 4...  6.575121e+05
#
#       area_covered  service_coverage  bus_stops  density_bstops  routesum  \
# 0     2.198917e+05          0.538065        3.0       -0.570574 -0.676593
# 1     4.397288e+05          0.538065       13.0        0.607097 -0.335144
# 2     4.393132e+05          0.538065       13.0        0.609166 -0.011365
# 3     3.235872e+05          0.538065        9.0        0.477613 -0.144689
# 4     3.243118e+05          0.538065       12.0        1.157279 -0.540348
# ...            ...               ...        ...             ...       ...
# 1324  5.303250e+05          0.531499       12.0        0.091703 -0.439181
# 1325  1.173475e+06         -2.753697       13.0       -1.330830  0.133881
# 1327  3.942156e+05          0.535305        6.0       -0.454577 -0.305411
# 1328  8.576700e+05          0.474823       29.0        0.887937  0.449529
# 1329  6.575121e+05          0.538065       19.0        0.557767 -0.202021
#
#       wheelchair_stops  transit_supply_score       quartile
# 0            -1.121122             -1.830223            Low
# 1             0.055983              0.866000  Moderate-High
# 2             0.055983              1.191848  Moderate-High
# 3            -0.414859              0.456130  Moderate-High
# 4            -0.061728              1.093268  Moderate-High
# ...                ...                   ...            ...
# 1324         -0.061728              0.122292  Moderate-High
# 1325          0.055983             -3.894664            Low
# 1327         -0.767990             -0.992674   Moderate-Low
# 1328          1.821639              3.633928           High
# 1329          0.762245              1.656057           High
#
# [881 rows x 13 columns]

# %%
#MIGHT NOT NEED THIS BECAUSE IT IS ALREADY A GDF
gdf = gpd.GeoDataFrame(cook_dropped, geometry=cook_dropped['geometry'])

# %%
# Convert the categorical column to a string
gdf['quartile'] = gdf['quartile'].astype(str)


gdf.to_file(r"C:\Users\cathk\GEOG490\chicago_transit_supply.shp")
# Out:
# WARNING:fiona._env:Normalized/laundered field name: 'area_covered' to 'area_cover'
# WARNING:fiona._env:Normalized/laundered field name: 'service_coverage' to 'service_co'
# WARNING:fiona._env:Normalized/laundered field name: 'density_bstops' to 'density_bs'
# WARNING:fiona._env:Normalized/laundered field name: 'wheelchair_stops' to 'wheelchair'
# WARNING:fiona._env:Normalized/laundered field name: 'transit_supply_score' to 'transit_su'

# %%
# Load Chicago Boundary
boundary = gpd.read_file(r"C:\Users\cathk\GEOG490\cityboundary.shp")
# Out:
# ERROR:fiona._env:PROJ: proj_identify: C:\Users\cathk\miniconda3\Library\share\proj\proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.
# ERROR:fiona._env:PROJ: proj_identify: C:\Users\cathk\miniconda3\Library\share\proj\proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.

# %%
# Define the GeoDataFrame (you should replace this with your actual data loading code)
# Ensure 'quartile' column exists and contains the expected values
print(gdf['quartile'].value_counts())

# Define a color map for the quartiles
quartile_colors = {
    'Low': 'blue',
    'Moderate-Low': 'cyan',
    'Moderate-High': 'orange',
    'High': 'red'
}

# Plot the GeoDataFrame with the specified colors for quartiles
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

gdf.plot(column='quartile', 
         ax=ax, 
         legend=True,
         legend_kwds={'title': "Transit Dependency Quartiles"},
         color=[quartile_colors[q] for q in gdf['quartile']])

# Add a title and axes labels
ax.set_title('Transit Dependency by Census Tract')
ax.set_axis_off()

# Show the plot
plt.show()
# Out:
# quartile
# Low              221
# Moderate-High    220
# Moderate-Low     220
# High             220
# Name: count, dtype: int64

# %%
# !pip install contextily
# Out:
# Collecting contextily
#   Downloading contextily-1.5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: matplotlib in c:\users\cathk\.gds\lib\site-packages (from contextily) (3.7.5)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#      ------------ ------------------------ 41.0/125.4 kB 487.6 kB/s eta 0:00:01
#      ------------------------------------ 125.4/125.4 kB 921.6 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\cathk\.gds\lib\site-packages (from contextily) (2.31.0)
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in c:\users\cathk\.gds\lib\site-packages (from contextily) (10.3.0)
# Requirement already satisfied: rasterio in c:\users\cathk\.gds\lib\site-packages (from contextily) (1.3.9)
# Requirement already satisfied: xyzservices in c:\users\cathk\.gds\lib\site-packages (from contextily) (2023.10.1)
# Requirement already satisfied: joblib in c:\users\cathk\.gds\lib\site-packages (from contextily) (1.3.2)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (4.50.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (24.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (1.24.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\cathk\.gds\lib\site-packages (from matplotlib->contextily) (6.4.0)
# Requirement already satisfied: click>=3.0 in c:\users\cathk\.gds\lib\site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: attrs in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (23.2.0)
# Requirement already satisfied: click-plugins in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (56.0.0)
# Requirement already satisfied: affine in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: certifi in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (2024.2.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: cligj>=0.5 in c:\users\cathk\.gds\lib\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cathk\.gds\lib\site-packages (from requests->contextily) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cathk\.gds\lib\site-packages (from requests->contextily) (1.26.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cathk\.gds\lib\site-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: colorama in c:\users\cathk\.gds\lib\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\cathk\.gds\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->contextily) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\cathk\.gds\lib\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Installing collected packages: geographiclib, mercantile, geopy, contextily
# Successfully installed contextily-1.5.2 geographiclib-2.0 geopy-2.4.1 mercantile-1.2.1
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#add in supply gdf here

# %%
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import box  # Import the box function
import matplotlib.patches as mpatches


# Ensure both GeoDataFrames use the same CRS
gdf.crs = boundary.crs

# Get the bounding box of the city boundary
minx, miny, maxx, maxy = boundary.total_bounds

# Clip the GeoDataFrame to the city boundary
clip_box = box(minx, miny, maxx, maxy)

#gdf = gdf[gdf.geometry.intersects(clip_box)]

# Define a color map for the quartiles
quartile_colors = {
    'Low': "#e1a69298",
    'Moderate-Low': "#de6e5698",
    'Moderate-High': "#b0001b98",
    'High': "#540f0f98"
}

# Plotting the GeoDataFrame
fig, ax = plt.subplots(1, 1, figsize=(14, 14))

# Specify the CRS for the basemap
basemap_crs = gdf.crs.to_string()

# Plot the GeoDataFrame with the specified CRS
gdf.plot(ax=ax,
         legend=True,
         legend_kwds={'title': "Transit Demand Quartiles"},
         color=[quartile_colors[q] for q in gdf['quartile']],
         edgecolor='black')

# Add a basemap with the same CRS as the GeoDataFrame
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, zoom=12, crs=gdf.crs)

# Add a legend with custom color patches
legend_handles = [mpatches.Patch(color=color, label=label) for label, color in quartile_colors.items()]
ax.legend(handles=legend_handles, title='Transit Supply Quartiles', loc='lower right')


# Add a title and axes labels
ax.set_title('Transit Supply by Census Tract')
ax.set_axis_off()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CPLE_BaseError                            Traceback (most recent call last)
# File rasterio\\crs.pyx:775, in rasterio.crs.CRS.from_user_input()
#
# File rasterio\\_err.pyx:209, in rasterio._err.exc_wrap_ogrerr()
#
# CPLE_BaseError: OGR Error code 6
#
# During handling of the above exception, another exception occurred:
#
# CRSError                                  Traceback (most recent call last)
# Cell In[110], line 40
#      33 gdf.plot(ax=ax,
#      34          legend=True,
#      35          legend_kwds={'title': "Transit Demand Quartiles"},
#      36          color=[quartile_colors[q] for q in gdf['quartile']],
#      37          edgecolor='black')
#      39 # Add a basemap with the same CRS as the GeoDataFrame
# ---> 40 ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, zoom=12, crs=gdf.crs)
#      42 # Add a legend with custom color patches
#      43 legend_handles = [mpatches.Patch(color=color, label=label) for label, color in quartile_colors.items()]
#
# File ~\.gds\lib\site-packages\contextily\plotting.py:130, in add_basemap(ax, zoom, source, interpolation, attribution, attribution_size, reset_extent, crs, resampling, zoom_adjust, **extra_imshow_args)
#     128 # Convert extent from `crs` into WM for tile query
#     129 if crs is not None:
# --> 130     left, right, bottom, top = _reproj_bb(
#     131         left, right, bottom, top, crs, "epsg:3857"
#     132     )
#     133 # Download image
#     134 image, extent = bounds2img(
#     135     left, bottom, right, top, zoom=zoom, source=source, ll=False, zoom_adjust=zoom_adjust
#     136 )
#
# File ~\.gds\lib\site-packages\contextily\plotting.py:220, in _reproj_bb(left, right, bottom, top, s_crs, t_crs)
#     219 def _reproj_bb(left, right, bottom, top, s_crs, t_crs):
# --> 220     n_l, n_b, n_r, n_t = transform_bounds(s_crs, t_crs, left, bottom, right, top)
#     221     return n_l, n_r, n_b, n_t
#
# File ~\.gds\lib\site-packages\rasterio\warp.py:148, in transform_bounds(src_crs, dst_crs, left, bottom, right, top, densify_pts)
#     121 """Transform bounds from src_crs to dst_crs.
#     122
#     123 Optionally densifying the edges (to account for nonlinear transformations
#    (...)
#     145     Outermost coordinates in target coordinate reference system.
#     146 """
#     147 src_crs = CRS.from_user_input(src_crs)
# --> 148 dst_crs = CRS.from_user_input(dst_crs)
#     149 return _transform_bounds(
#     150     src_crs,
#     151     dst_crs,
#    (...)
#     156     densify_pts,
#     157 )
#
# File rasterio\\crs.pyx:777, in rasterio.crs.CRS.from_user_input()
#
# CRSError: The WKT could not be parsed. OGR Error code 6
